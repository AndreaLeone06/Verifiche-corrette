# %%
x = ['apple', 'orange']
y = ['carrot','potato']
z = [x,y]
print(z[0][0])

# %%
num = [0,1,2,12,4,5,6,7,8,9]
print(num[0:4])
print(num[:7:3])
len(num)

# %%
print("min =",min(num),"  max =",max(num),"  total =",sum(num))
[1,2,3] + [5,4,7]

# %%
mlist = ['bzaa','ds','nc','az','z','klm']
print("max =",max(mlist))
print("min =",min(mlist))
print('longest =',max(mlist, key=len))
print('shortest =',min(mlist, key=len))

# %%
print(list('hello world !'),'Hello   World !!'.split())

# %%
lst = [1,1,4,8,7]
lst.append(1)
print(lst)
