# %% [markdown]
# 1. si vogliono memorizzare i valori del cambio tra € e $ negli ultimi 7 giorni

# %%
valoriCambio = [0.9863, 0.9766, 0.9778, 0.9168, 0.9858, 0.9857, 0.9828]
giorni = ["18/10", "19/10", "20/10", "21/10", "22/10", "23/10", "24/10",]

# %% [markdown]
# 2. trovare il giorno in cui il dollaro valeva di più

# %%
print(giorni[valoriCambio.index(max(valoriCambio))])
# Out:
# 18/10

# %% [markdown]
# 3. trovare quanto valeva il dollaro una settimana fa

# %%
print(valoriCambio[giorni.index("18/10")])
# Out:
# 0.9863

# %% [markdown]
# 4. trovare i valori del dollaro nel periodo compreso tra 5 giorni fa e 3 giorno fa

# %%
valoriCambio2 = [0.9721, 0.9721, 0.0.9863, 0.9766, 0.9778, 0.9168, 0.9858, 0.9857, 0.9828]
